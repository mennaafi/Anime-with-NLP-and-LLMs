# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer
from datasets import Dataset

# %% [markdown]
# ## Load our crawled dataset :

# %%
dataset_path = "../data/crawled_data/jutsus.jsonl"
df = pd.read_json(dataset_path , lines = True)
df.head()
# Out:
#                        jutsu_name  \
# 0                    10 Hit Combo
# 1                       Amaterasu
# 2          Amaterasu: Wailing Sky
# 3                     Amenominaka
# 4  Amaterasu: Flame Wrapping Fire
#
#                                           jutsu_type  \
# 0                                           Taijutsu
# 1                   Kekkei Genkai, Ninjutsu, Dōjutsu
# 2                   Kekkei Genkai, Dōjutsu, Ninjutsu
# 3  Kekkei Mōra, Ninjutsu, Space–Time Ninjutsu, Dō...
# 4                   Kekkei Genkai, Ninjutsu, Dōjutsu
#
#                                    jutsu_description
# 0  Lars punches the opponent before striking them...
# 1  This article is about the ninjutsu Amaterasu. ...
# 2  Using Susanoo, Indra sends Amaterasu to the sk...
# 3  Using her Rinne Sharingan, Kaguya Ōtsutsuki re...
# 4  The manipulated flames of Amaterasu are used t...

# %%
def simplify_jutsu(jutsu):
    if "Taijutsu" in jutsu:
        return "Taijutsu"
    if "Ninjutsu" in jutsu:
        return "Ninjutsu"
    if "Genjutsu" in jutsu:
        return "Genjutsu"

# %%
df['jutsu_type_simplified'] = df['jutsu_type'].apply(simplify_jutsu)
df.head()
# Out:
#                        jutsu_name  \
# 0                    10 Hit Combo
# 1                       Amaterasu
# 2          Amaterasu: Wailing Sky
# 3                     Amenominaka
# 4  Amaterasu: Flame Wrapping Fire
#
#                                           jutsu_type  \
# 0                                           Taijutsu
# 1                   Kekkei Genkai, Ninjutsu, Dōjutsu
# 2                   Kekkei Genkai, Dōjutsu, Ninjutsu
# 3  Kekkei Mōra, Ninjutsu, Space–Time Ninjutsu, Dō...
# 4                   Kekkei Genkai, Ninjutsu, Dōjutsu
#
#                                    jutsu_description jutsu_type_simplified
# 0  Lars punches the opponent before striking them...              Taijutsu
# 1  This article is about the ninjutsu Amaterasu. ...              Ninjutsu
# 2  Using Susanoo, Indra sends Amaterasu to the sk...              Ninjutsu
# 3  Using her Rinne Sharingan, Kaguya Ōtsutsuki re...              Ninjutsu
# 4  The manipulated flames of Amaterasu are used t...              Ninjutsu

# %%
df['jutsu_type_simplified'].value_counts()
# Out:
# jutsu_type_simplified
# Ninjutsu    2044
# Taijutsu     637
# Genjutsu      82
# Name: count, dtype: int64

# %% [markdown]
# ### - Skewed dataset !

# %%
df['text'] = df['jutsu_name'] + ". " + df['jutsu_description']
df['jutsus'] = df['jutsu_type_simplified']
df = df[['text', 'jutsus']]
df = df.dropna()

# %%
df.head()
# Out:
#                                                 text    jutsus
# 0  10 Hit Combo. Lars punches the opponent before...  Taijutsu
# 1  Amaterasu. This article is about the ninjutsu ...  Ninjutsu
# 2  Amaterasu: Wailing Sky. Using Susanoo, Indra s...  Ninjutsu
# 3  Amenominaka. Using her Rinne Sharingan, Kaguya...  Ninjutsu
# 4  Amaterasu: Flame Wrapping Fire. The manipulate...  Ninjutsu

# %% [markdown]
# ### some cleaning text column :

# %%
from bs4 import BeautifulSoup
class Cleaner():
    def __init__(self):
        pass 
    
    def put_line_breaks(self, text):
        return text.replace("<\p>", "<\p>\n")
    
    def remove_html_tags(self, text):
        clean_text = BeautifulSoup(text, "lxml").text
        return clean_text

    def clean(self, text):
        text = self.put_line_breaks(text)
        text = self.remove_html_tags(text)
        text = text.strip()
        return text
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\user\AppData\Local\Temp\ipykernel_3480\3655626712.py:7: SyntaxWarning: invalid escape sequence '\p'
#   return text.replace("<\p>", "<\p>\n")
# C:\Users\user\AppData\Local\Temp\ipykernel_3480\3655626712.py:7: SyntaxWarning: invalid escape sequence '\p'
#   return text.replace("<\p>", "<\p>\n")

# %%
text_column_name = 'text'
label_column_name = 'jutsus'

# %%
cleaner = Cleaner()
df['text_cleaned'] = df[text_column_name].apply(cleaner.clean)
df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3480\3655626712.py:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text, "lxml").text
#                                                 text    jutsus  \
# 0  10 Hit Combo. Lars punches the opponent before...  Taijutsu
# 1  Amaterasu. This article is about the ninjutsu ...  Ninjutsu
# 2  Amaterasu: Wailing Sky. Using Susanoo, Indra s...  Ninjutsu
# 3  Amenominaka. Using her Rinne Sharingan, Kaguya...  Ninjutsu
# 4  Amaterasu: Flame Wrapping Fire. The manipulate...  Ninjutsu
#
#                                         text_cleaned
# 0  10 Hit Combo. Lars punches the opponent before...
# 1  Amaterasu. This article is about the ninjutsu ...
# 2  Amaterasu: Wailing Sky. Using Susanoo, Indra s...
# 3  Amenominaka. Using her Rinne Sharingan, Kaguya...
# 4  Amaterasu: Flame Wrapping Fire. The manipulate...

# %% [markdown]
# ### Encode Label  :

# %%
le = preprocessing.LabelEncoder()
le.fit(df[label_column_name].tolist())
# Out:
# LabelEncoder()

# %%
df[label_column_name]
# Out:
# 0       Taijutsu
# 1       Ninjutsu
# 2       Ninjutsu
# 3       Ninjutsu
# 4       Ninjutsu
#           ...
# 2926    Ninjutsu
# 2927    Taijutsu
# 2928    Taijutsu
# 2929    Taijutsu
# 2930    Ninjutsu
# Name: jutsus, Length: 2763, dtype: object

# %%
label_dict = {index:label_name for index, label_name in enumerate(le.__dict__['classes_'].tolist())}
label_dict
# Out:
# {0: 'Genjutsu', 1: 'Ninjutsu', 2: 'Taijutsu'}

# %%
df['label'] = le.transform(df[label_column_name].tolist())
df.head()
# Out:
#                                                 text    jutsus  \
# 0  10 Hit Combo. Lars punches the opponent before...  Taijutsu
# 1  Amaterasu. This article is about the ninjutsu ...  Ninjutsu
# 2  Amaterasu: Wailing Sky. Using Susanoo, Indra s...  Ninjutsu
# 3  Amenominaka. Using her Rinne Sharingan, Kaguya...  Ninjutsu
# 4  Amaterasu: Flame Wrapping Fire. The manipulate...  Ninjutsu
#
#                                         text_cleaned  label
# 0  10 Hit Combo. Lars punches the opponent before...      2
# 1  Amaterasu. This article is about the ninjutsu ...      1
# 2  Amaterasu: Wailing Sky. Using Susanoo, Indra s...      1
# 3  Amenominaka. Using her Rinne Sharingan, Kaguya...      1
# 4  Amaterasu: Flame Wrapping Fire. The manipulate...      1

# %%
df_train , df_test = train_test_split(
    df,
    test_size =.2,
    random_state = 42,
    stratify=df['label']
)

# %% [markdown]
# ####    by adding  stratify :  ensure that the training and testing sets have approximately the same distribution of classes as the original dataset.

# %%
df['jutsus'].value_counts()
# Out:
# jutsus
# Ninjutsu    2044
# Taijutsu     637
# Genjutsu      82
# Name: count, dtype: int64

# %%
df_train['jutsus'].value_counts()
# Out:
# jutsus
# Ninjutsu    1635
# Taijutsu     509
# Genjutsu      66
# Name: count, dtype: int64

# %%
model_name = "distilbert/distilbert-base-uncased"

# %%
# Load the tokenizer for the  model  
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
def preprocess_function(tokenizer,examples):
    return tokenizer(examples['text_cleaned'],truncation=True)

# %%
# Conver Pandas to a hugging face dataset
train_dataset = Dataset.from_pandas(df_train)
test_dataset = Dataset.from_pandas(df_test)

# %%
# tokenize the dataset
tokenized_train = train_dataset.map(lambda examples: preprocess_function(tokenizer, examples),
                                    batched=True)
tokenized_test = test_dataset.map(lambda examples: preprocess_function(tokenizer, examples),
                                                                      batched=True)
# Out:
# Map: 100%|██████████| 2210/2210 [00:00<00:00, 3295.16 examples/s]
# Map: 100%|██████████| 553/553 [00:00<00:00, 3425.92 examples/s]
